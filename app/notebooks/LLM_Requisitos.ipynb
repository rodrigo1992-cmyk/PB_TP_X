# %% [markdown]
# ### Selecionados 3 textos criação do Conjunto Verdade, que servirá para avaliação dos resultados

# %%
set_verdade = set({'ETL','Office','SQL','Python','R','Go','Power BI','Pentaho','Tableau','Apache NiFi','Talend','Glue','Airflow','SQL Server','PostgreSQL','Looker','Pandas','Scikit-learn','Machine Learning','Data Warehouses','Data Lakes', 'Azure', 'AWS', 'Databricks', 'Spark', 'Azure Data Factory', 'Azure Event Hubs', 'NoSQL', 'DevOps', 'Java', 'Scala', 'Dynatrace', 'Splunk', 'ELK', 'Grafana', 'OpenTelemetry', 'algoritmos', 'backend java', 'business intelligence','PL-330','advanced analytics'})

descricao_vaga_portugues_orig = [
    "Para agregar nosso time, suas principais atividades a serem exercidas serão:  Executar atividades de extração, transformação e carregamento (ETL) de dados, assegurando a integridade e precisão das informações processadas. Desenvolver e manter dashboards interativos para visualização e análise de dados, adaptando-os às necessidades dos stakeholders. Criar e monitorar indicadores-chave de performance (KPIs). Automatizar processos para melhorar a eficiência e reduzir erros. Realizar análises estatísticas para gerar insights que apoiem a tomada de decisões e contribuir com valores incrementais. Garantir a entrega dos projetos dentro dos prazos estipulados, mantendo padrões de qualidade e otimizando recursos técnicos e materiais. Colaborar com stakeholders para entender e atender às suas necessidades, promovendo a melhoria contínua dos processos, assegurando a entrega de relatórios e apresentações gerenciais sobre os resultados e progresso dos projetos.  Vamos adorar caso você possa contribuir com as seguintes competências: Superior em alguns dos cursos: Engenharia da Computação, Sistemas da Informação, Inteligência de Negócio, Estatística ou áreas correlatas;  Experiência sólida nas seguintes ferramentas: SQL, Python, Power BI e Pentaho; Pacote office completo; Conhecimento em ETL; Inglês intermediário; Capacidade de adaptação.",
    "Projetar, construir e manter pipelines de dados robustos e escaláveis;- Desenvolver e gerenciar processos de ETL para integrar dados de múltiplas fontes em data warehouses e data lakes;- Colaborar com equipes de negócios e TI para definir e entender requisitos de dados e relatórios;- Criar dashboards e relatórios interativos usando ferramentas de BI (como Power BI, Tableau, etc.) para suportar a tomada de decisão;- Analisar grandes conjuntos de dados para identificar tendências, padrões e insights estratégicos;- Garantir a qualidade dos dados e a governança de dados através de práticas rigorosas de monitoramento e validação. - Superior Completo em Ciência da Computação, Engenharia de Dados, Análise de Dados ou áreas relacionadas;- Sólida experiência em SQL e outras linguagens de consulta e manipulação de dados;- Conhecimento avançado em ferramentas de ETL (como Apache NiFi, Talend, Glue, Airflow);- Experiência com sistemas de banco de dados relacional (SQL Server, PostgreSQL, etc.);- Familiaridade com ferramentas de BI (Power BI, Tableau, Looker, etc.) e linguagens de programação (Python, Go);- Habilidade comprovada na criação de relatórios e visualizações de dados que comunicam insights de forma clara e eficaz;- Experiência com arquitetura de data lakes e data warehouses;- Excelentes habilidades de comunicação e colaboração;- Proatividade e capacidade de resolver problemas complexos de maneira criativa",
    "Ciência de Dados  para  a Gerência Executiva, profissional  STEM (Science, Technology, Engineering, and Mathematics) - com a responsabilidade de suportar os  processos;Planejamento e Controle e Riscos  Operacionais  e de reporte à liderança Executiva;Suporte aos  processos  de Planejamento e Controle e Riscos  Operacionais, utilizando métodos quantitativos  de análise de dados  avançadas;Promover o avanço das  análise de dados  de forma  descritiva, para preditiva e,especialmente, prescritiva. As  análises  devem considerar os  diversos  KPI da árvore de valor das unidades  de negócio. experiência em análise de dados/business  analysts  e ciência de dados; ou logística, supply chain management e gestão de frotas  (schedulling); ou controle da  produção de óleo e gás; ou gestão de grandes  projetos  de engenharia; ou planejamento e controle (PCP).Sólida  experiência em ciência de dados, incluindo advanced analytics, modelos  preditivos  e prescritivos, clusterização machine learning  e otimização; Profissional certificado em POWER BI pela Microsoft 70-778, PL-330, 70-799 ou equivalente;Programação avançada em Python/R (incluindo pacotes  open-source - Pandas, Scikit-learn, etc.); Desejável conhecimento em SQL para consulta de base de dados  e geração de análises;Conhecimentos  e habilidades  em algoritmos  e estruturas  de dados;Nivel Superior em Engenharia, Com registro regular no respectivo conselho de classe.",
    "Requisitos e qualificações. Pra mandar bem nessa oportunidade você precisa manjar das tecnologias:(Conhecimentos técnicos obrigatórios) Experiência com desenvolvimento na nuvem (Azure e/ou AWS), com conhecimento depráticas para otimização de custos; Vasta experiência em engenharia de dados e data lake, com foco na construção depipelines de dados escaláveis utilizando Databricks e Spark; Excelentes noções de arquitetura e system design, sabendo lidar com grandes volumes de dados em batch e real time; Conhecimento avançado em ferramentas de dados como o Azure Data Factory (ou equivalentes) e Azure Event Hubs (ou equivalentes); Experiência com bancos de dados relacionais e bancos de dados NoSQL; Experiência com ferramentas de DevOps, CI/CD; Conhecimento avançado em Java e/ou Scala para pipelines de manipulação de dados; Conhecimento profundo de SQL; Conhecimento em testes unitários e automatizados; e Experiência de implantação de mecanismos de observabilidade de dados. Vai ser bom se você também tiver:(Conhecimentos técnicos desejáveis, que serão um diferencial)Conhecimento de práticas e ferramentas do BI tradicional; Conhecimentos em Dynatrace, Splunk, ELK, Grafana, OpenTelemetry; e Conhecimentos de Backend Java. O que não abrimos mão:(Soft Skills) Colaboração; Proatividade; e Trabalho em equipe.Informações adicionais Para esta posição oferecemos: Salário CLT Full; Vale Refeição ou Alimentação (Alelo); Vale Transporte (sempre que houver o deslocamento); Auxílio Home Office (proporcional aos dias em que atuará nesta modalidade); Assistência Médica Sulamérica; Assistência Odontológica Sulamérica; Seguro de Vida; Parcerias (Curso de idiomas, ensino, livraria, restaurante, entre outras); Gympass; Allya; Day Off; Premiação por indicações; Inside Out (Ocorre todas as quartas-feiras. Evento da galera voltado para troca deconhecimento); Oportunidade de crescimento profissional. Etapas do processo; A Solutis é Digital! Somos apaixonados por tecnologia e esse valor está presente em nossas ações e proposta de trabalho. Ambiente descontraído e criativo, horário flexível, possibilidade de trabalho home office, eventos e programas internos com games... Isso faz parte do nosso dia-a-dia. Engajamento, busca intensa por conhecimento, empatia e criatividade são a nossa receita para cultivar e colher, sempre, o melhor resultado tecnológico. Essa é a Solutis, flexível, acolhedora, inquieta, amante da tecnologia e de tudo que ela nos proporciona de mais incrível. Venha fazer parte do nosso time!"
    ]

descricao_vaga_ingles_orig = [
    "To enhance our team, your main activities will include: Executing data extraction, transformation, and loading (ETL) activities, ensuring the integrity and accuracy of the processed information. Developing and maintaining interactive dashboards for data visualization and analysis, adapting them to the needs of stakeholders. Creating and monitoring key performance indicators (KPIs). Automating processes to improve efficiency and reduce errors. Conducting statistical analyses to generate insights that support decision-making and contribute incremental value. Ensuring the delivery of projects within the stipulated deadlines, maintaining quality standards, and optimizing technical and material resources. Collaborating with stakeholders to understand and meet their needs, promoting continuous improvement of processes, ensuring the delivery of reports and management presentations on project results and progress. We would love it if you could contribute with the following skills: A degree in some of the following fields: Computer Engineering, Information Systems, Business Intelligence, Statistics, or related areas; Solid experience with the following tools: SQL, Python, Power BI, and Pentaho; Complete Office package; Knowledge in ETL; Intermediate English; Adaptability.",
    "Design, build, and maintain robust and scalable data pipelines; - Develop and manage ETL processes to integrate data from multiple sources into data warehouses and data lakes; - Collaborate with business and IT teams to define and understand data and reporting requirements; - Create dashboards and interactive reports using BI tools (such as Power BI, Tableau, etc.) to support decision-making; - Analyze large datasets to identify trends, patterns, and strategic insights; - Ensure data quality and data governance through rigorous monitoring and validation practices. - Bachelor's degree in Computer Science, Data Engineering, Data Analysis, or related fields; - Solid experience in SQL and other data query and manipulation languages; - Advanced knowledge of ETL tools (such as Apache NiFi, Talend, Glue, Airflow); - Experience with relational database systems (SQL Server, PostgreSQL, etc.); - Familiarity with BI tools (Power BI, Tableau, Looker, etc.) and programming languages (Python, Go); - Proven ability to create reports and data visualizations that communicate insights clearly and effectively; - Experience with data lake and data warehouse architecture; - Excellent communication and collaboration skills; - Proactivity and ability to solve complex problems creatively.",
    "Data Science for Executive Management, STEM (Science, Technology, Engineering, and Mathematics) professional - responsible for supporting processes; Planning and Control and Operational Risks and reporting to Executive leadership; Support for Planning and Control and Operational Risks processes, using quantitative methods for advanced data analysis; Promote the advancement of data analysis from descriptive to predictive and especially prescriptive. The analyses must consider the various KPIs of the value tree of the business units. Experience in data analysis/business analysis and data science; or logistics, supply chain management, and fleet management (scheduling); or oil and gas production control; or management of large engineering projects; or planning and control (PCP). Solid experience in data science, including advanced analytics, predictive and prescriptive models, clustering, machine learning, and optimization; Certified professional in POWER BI by Microsoft 70-778, PL-330, 70-799, or equivalent; Advanced programming in Python/R (including open-source packages - Pandas, Scikit-learn, etc.); Desirable knowledge in SQL for database querying and analysis generation; Knowledge and skills in algorithms and data structures; Higher education in Engineering, with regular registration in the respective professional council.",
    "Requirements and qualificationsTo succeed in this opportunity, you need to be a technology proficient: (Required technical knowledge) Experience with cloud development (Azure and/or AWS), with knowledge of practices for cost optimization; Extensive experience in data engineering and data lake, with a focus on building scalable data pipelines using Databricks and Spark; Excellent knowledge of architecture and system design, knowing how to handle large volumes of data in batch and real time; Advanced knowledge of data tools such as Azure Data Factory (or equivalent) and Azure Event Hubs (or equivalent); Experience with relational databases and NoSQL databases; Experience with DevOps, CI/CD tools; Advanced knowledge of Java and/or Scala for data manipulation pipelines; Deep knowledge of SQL; Knowledge of unit and automated testing; and Experience in implementing data observability mechanisms. It will be good if you also have: (Desirable technical knowledge, which will be a differential) Knowledge of traditional BI practices and tools; Knowledge of Dynatrace, Splunk, ELK, Grafana, OpenTelemetry; and Knowledge of Java Backend What we do not give up: (Soft Skills) Collaboration; Proactivity; and Teamwork. Additional informationFor this position we offer:Full CLT Salary;Meal or Food Voucher (Alelo);Transportation Voucher (whenever there is a commute);Home Office Assistance (proportional to the days in which you will work in this modality);Sulamérica Medical Assistance;Sulamérica Dental Assistance;Life Insurance;Partnerships (Language course, teaching, bookstore, restaurant, among others);Gympass;Allya;Day Off;Referral Awards;Inside Out (Occurs every Wednesday. Event for the group focused on exchanging knowledge);Opportunity for professional growth.Process stagesSolutis is Digital!We are passionate about technology and this value is present in our actions and work proposal. A relaxed and creative environment, flexible hours, the possibility of working from home, events and internal programs with games... This is part of our daily routine. Engagement, an intense search for knowledge, empathy and creativity are our recipe for always cultivating and harvesting the best technological results. This is Solutis, flexible, welcoming, restless, a lover of technology and everything incredible that it provides us. Come be part of our team!"]

# transformando tudo em maiúsculo
# descricao_vaga_portugues = descricao_vaga_portugues.upper()
# descricao_vaga_ingles = descricao_vaga_ingles.upper()

# %%
def pre_tratamento_pontuacao(descricao_vaga):
    descricao_vaga = descricao_vaga.replace(";", ", ")
    descricao_vaga = descricao_vaga.replace("(", ", ")
    descricao_vaga = descricao_vaga.replace("),", ", ")
    descricao_vaga = descricao_vaga.replace(")", ", ")
    descricao_vaga = descricao_vaga.replace("/", ", ")
    descricao_vaga = descricao_vaga.replace(".", ". ")
    descricao_vaga = descricao_vaga.replace("|", ", ")
    descricao_vaga = descricao_vaga.replace(",", ", ")
    descricao_vaga = descricao_vaga.replace(",,", ", ")
    descricao_vaga = descricao_vaga.replace("  ", " ")
    descricao_vaga = descricao_vaga.replace(",, ", ", ")
    descricao_vaga = descricao_vaga.replace(", .", ".")
    descricao_vaga = descricao_vaga.replace(". ,", ".")

    return descricao_vaga

def tratar_lista(lst_resp):
    #splitar a lista de software
    lst_sw = [item.replace(" and ", ",").replace(" e ", ",").replace(", ", ",") for item in lst_resp]
    lst_sw = [item.split(",") for item in lst_sw]

    #trasnformar a lista em um conjunto
    set_sw = set()
    for item in lst_sw:
        set_sw.update(item)
    
    return set_sw

# %%
descricao_vaga_portugues = []
descricao_vaga_ingles = []


for i in descricao_vaga_portugues_orig:
    descricao_vaga_portugues.append(pre_tratamento_pontuacao(i))

for i in descricao_vaga_ingles_orig:
    descricao_vaga_ingles.append(pre_tratamento_pontuacao(i))

# %% [markdown]
# # Teste 1 - Modelo Tiny Roberta - Em Inglês

# %% [markdown]
# #### O modelo de QA Tiny Roberta só retorna a primeira sequência dentro do texto. Ou seja, se os softwares forem citados em frases distintas o modelo só irá retornar a primeira ocorrência.

# %%
from transformers import pipeline

pipe = pipeline("question-answering", model="deepset/tinyroberta-squad2")

prompt = "Which softwares and technologies are mentioned in the text?"
lst_resp = []

for vaga in descricao_vaga_ingles:
    resposta = pipe(question = prompt, context = vaga)
    lst_resp.append(resposta['answer'])

set_sw_TinyBerta = tratar_lista(lst_resp)
set_sw_TinyBerta
# Out:
# {'',
#  ' Collaboration',
#  ' Proactivity',
#  'Create dashboards',
#  'Engineering',
#  'Mathematics',
#  'Pentaho',
#  'Power BI',
#  'Python',
#  'SQL',
#  'Science',
#  'Soft Skills',
#  'Teamwork',
#  'Technology',
#  'interactive reports using BI tools'}

# %% [markdown]
# # Teste 2 - Modelo Bert - Fining Tuning em Português

# %% [markdown]
# #### O modelo de QA Bert PT retornou o mesmo resultado do Tiny Roberta, dispensando a tradução do contexto para inglês.

# %%
pipe = pipeline("question-answering", model="pierreguillou/bert-base-cased-squad-v1.1-portuguese")

prompt = "Quais softwares e tecnologias são mencionados no texto?"
lst_resp = []

for vaga in descricao_vaga_portugues:
    resposta = pipe(question = prompt, context = vaga)
    lst_resp.append(resposta['answer'])

set_sw_BertPT = tratar_lista(lst_resp)
set_sw_BertPT
# Out:
# {'Azure e',
#  'Looker',
#  'Pentaho',
#  'Power BI',
#  'Python',
#  'SQL',
#  'STEM ',
#  'Science',
#  'Tableau',
#  'ou AWS'}

# %% [markdown]
# # Teste 3 - Modelo Bert - Fining Tuning em Português
# ### Abordagem passando uma frase por vez
# #### Nesta abordagem, mesmo que não exista uma resposta na frase o modelo retorna algo, trazendo uma grande quantidade de falsos positivos. Para melhorar, fiz um filtro no Score baixo, removendo boa parte dos falsos positivos.

# %%
from transformers import pipeline
import pandas as pd

pipe = pipeline("question-answering", model="pierreguillou/bert-base-cased-squad-v1.1-portuguese")

prompt = "Quais softwares e tecnologias são mencionados no texto?"

lst_resp = []

for vaga in descricao_vaga_portugues:
    lista_frases = vaga.split(".")
    for frase in lista_frases:
        if frase:
            resposta = pipe(question = prompt, context = frase)
            lst_resp.append(resposta)

#converter o valor de científico para float
df = pd.DataFrame(lst_resp)

#arredondar o score e filtrar o score
df['score'] = df['score'].apply(lambda x: round(x, 6))
df.sort_values(by='score', ascending=False, inplace=True)
df
# Out:
#        score  start  end                                             answer
# 7   0.958549    259  290                    SQL, Python, Power BI e Pentaho
# 18  0.863313    117  149                   algoritmos e estruturas de dados
# 27  0.788811    102  130                       programas internos com games
# 21  0.672291    154  169                                    Azure e, ou AWS
# 22  0.554953    224  253                      Conhecimentos de Backend Java
# 0   0.528854    141  155                                     ETL,  de dados
# 12  0.516614     37   67                     BI , Power BI, Tableau, Looker
# 1   0.274613     22   32                                         dashboards
# 9   0.238010    362  384                             Power BI, Tableau, etc
# 24  0.224089    341  357                                   Curso de idiomas
# 23  0.139646     70   88                                 Trabalho em equipe
# ...

# %%
#Filtrando o score
df = df[df['score'] > 0.01]

#transformar a coluna answer em uma lista
lista_software = df['answer'].to_list()

set_sw_BertPT_V2 = tratar_lista(lista_software)

set_sw_BertPT_V2
# Out:
# {' de dados',
#  'Azure e',
#  'BI ',
#  'Conhecimentos de Backend Java',
#  'Curso de idiomas',
#  'ETL',
#  'KPI',
#  'KPIs',
#  'Looker',
#  'Pentaho',
#  'Power BI',
#  'Programação avançada em Python',
#  'Python',
#  'R',
#  'SQL',
#  'STEM ',
#  'Science',
#  'Tableau',
#  'Trabalho em equipe',
#  'algoritmos',
#  'busca intensa por conhecimento',
#  'criatividade',
#  'dashboards',
#  'empatia',
#  'estruturas de dados',
#  'etc',
#  'ou AWS',
#  'programas internos com games',
#  'sistemas de banco de dados relacional'}

# %% [markdown]
# # Teste 4 - Spacy em Inglês
# ### Modelo NLP de Extração de Entidades Nomeadas (NER)

# %% [markdown]
# #### Nesta abordagem a maior parte das entidades que desejo estão classificadas como ORG

# %%
#!python -m spacy download en_core_web_lg

# %%
import spacy

nlp = spacy.load("en_core_web_lg")

lst_resp = []

for vaga in descricao_vaga_ingles:
    doc = nlp(vaga)

    entidades = [ent.text for ent in doc.ents if ent.label_ == "ORG"]
    lst_resp.append(entidades)

#transformar a lista de lista em uma lista
lst_resp = [item for sublist in lst_resp for item in sublist]
lst_resp

set_sw_SpacyEN = tratar_lista(lst_resp)
set_sw_SpacyEN
# Out:
# {'AWS',
#  'Airflow',
#  'Azure',
#  'Azure Data Factory',
#  'Azure Event Hubs',
#  'BI',
#  'Business Intelligence',
#  'CI',
#  'Complete Office',
#  'Computer Engineering',
#  'Computer Science',
#  'Control',
#  'Data Analysis',
#  'Data Engineering',
#  'Data Science for Executive Management',
#  'Day Off',
#  'DevOps',
#  'ELK',
#  'ETL',
#  'Engineering',
#  'Food Voucher',
#  'Glue',
#  'Grafana',
#  'Home Office Assistance',
#  'Information Systems',
#  'Java',
#  'Knowledge of Dynatrace',
#  'Knowledge of Java Backend',
#  'Mathematics',
#  'Meal',
#  'Microsoft',
#  'NoSQL',
#  'OpenTelemetry',
#  'Operational Risks',
#  'PCP',
#  'POWER BI',
#  'Pentaho',
#  'Planning',
#  'Power BI',
#  'Python',
#  'Referral Awards',
#  'SQL',
#  'Scala',
#  'Science',
#  'Spark',
#  'Support for Planning',
#  'Talend',
#  'Teamwork',
#  'Technology',
#  'Transportation Voucher'}

# %% [markdown]
# # Teste 5 - Spacy em Português
# ### Modelo NLP de Extração de Entidades Nomeadas (NER)

# %% [markdown]
# ### Na versão em português as entidades estão mal classificadas. A maior parte das entidades que desejo estão classificadas como MISC ou como LOC

# %%
#!python -m spacy download pt_core_news_lg

# %%
import spacy

nlp = spacy.load("pt_core_news_lg")

lst_resp = []
lst_labes = []

for vaga in descricao_vaga_portugues:
    doc = nlp(vaga)

    entidades = [ent.text for ent in doc.ents if ent.label_ != "ORG"]
    lst_resp.append(entidades)

    labels = [ent.label_ for ent in doc.ents if ent.label_ != "ORG"]
    lst_labes.append(labels)

#juntar em uma única lista
lst_resp = [item for sublist in lst_resp for item in sublist]
lst_labels = [item for sublist in lst_labes for item in sublist]

set_sw_SpacyPT = tratar_lista(lst_resp)

for i in range(len(labels)):
    print(lst_labels[i], lst_resp[i])
# Out:
# LOC Superior
# MISC SQL
# MISC Python
# MISC Power BI
# MISC Pentaho
# MISC Inglês
# LOC Colaborar
# MISC BI
# MISC Power BI
# MISC Tableau
# MISC Superior Completo em Ciência da Computação, Engenharia de Dados
# MISC Análise de Dados
# LOC Sólida
# MISC SQL
# MISC Conhecimento
# MISC Apache NiFi
# LOC Talend
# LOC Glue
# LOC Airflow
# MISC SQL Server
# MISC PostgreSQL
# LOC Familiaridade
# MISC BI
# MISC Power BI
# MISC Tableau
# MISC Looker
# MISC Python
# MISC Go
# LOC Gerência Executiva
# MISC Riscos Operacionais
# MISC Suporte
# MISC Riscos Operacionais

# %% [markdown]
# # Comparando os Resultados

# %%
import regex as re

def tratar_respostas(item):
    item = item.lower()
    item = re.sub(r'^e\s+', '', item)
    item = re.sub(r'\s+e\s+', '', item)
    item = re.sub(r'\s+e$', '', item)
    item = re.sub(r'^ou\s+', '', item)
    item = re.sub(r'\s+ou\s+', '', item)
    item = re.sub(r'\s+ou$', '', item)

    return item

#juntar todos os conjuntos
set_sw = set_sw_TinyBerta.union(set_sw_BertPT).union(set_sw_BertPT_V2).union(set_sw_SpacyEN).union(set_sw_SpacyPT)

#converter todos os valores para minúsculo
set_sw = {item.lower() for item in set_sw}

#converter o conjunto em uma lista
lst_sw_completa = list(set_sw)
lst_sw_completa = [tratar_respostas(item) for item in lst_sw_completa]

# %%
df = pd.DataFrame(columns=['Termos','conjunto_verdade','TinyBerta', 'BertPT', 'BertPT_V2', 'SpacyEN', 'SpacyPT'])

df['Termos'] = lst_sw_completa

def checar_resultados(df, conj):
    conj_tratado = [tratar_respostas(item) for item in conj]
    avaliacao = []
    for termo in df['Termos']:
        if termo in conj_tratado:
            avaliacao.append(1)
        else: 
            avaliacao.append(0)
    return avaliacao

df['conjunto_verdade'] = checar_resultados(df, set_verdade)
df['TinyBerta'] = checar_resultados(df, set_sw_TinyBerta)
df['BertPT'] = checar_resultados(df, set_sw_BertPT)
df['BertPT_V2'] = checar_resultados(df, set_sw_BertPT_V2)
df['SpacyEN'] = checar_resultados(df, set_sw_SpacyEN)
df['SpacyPT'] = checar_resultados(df, set_sw_SpacyPT)

df
# Out:
#                                          Termos  conjunto_verdade  TinyBerta  \
# 0                                                               0          1
# 1                                           elk                 1          0
# 2                               complete office                 0          0
# 3                 conhecimentos de backend java                 0          0
# 4                                         scala                 1          0
# ..                                          ...               ...        ...
# 116                                     grafana                 1          0
# 117  superior completo em ciência da computação                 0          0
# 118                                     pentaho                 1          1
# 119                                      splunk                 1          0
# 120                        support for planning                 0          0
#
#      BertPT  BertPT_V2  SpacyEN  SpacyPT
# ...

# %%
#calcular a acurácia
def calcular_acertos(df, coluna_verdade, coluna_calcular):
    total_verdade = df[df[coluna_verdade] == 1].shape[0]
    total_respostas = df[df[coluna_calcular] == 1].shape[0]

    acertos = df[(df[coluna_verdade] == 1) & (df[coluna_calcular] == 1)].shape[0]

    perc_acerto = int(round((acertos / total_respostas) * 100, 0))

    erros = df[(df[coluna_verdade] == 0) & (df[coluna_calcular] == 1)].shape[0]
    perc_erros = int(round((erros / total_respostas) * 100 ,0))

    nao_preditos = df[(df[coluna_verdade] == 1) & (df[coluna_calcular] == 0)].shape[0]
    perc_nao_preditos = int(round((nao_preditos / total_verdade) * 100, 0))

    acuracia = int(round((acertos / total_verdade) * 100, 0))

    return total_respostas, acuracia, perc_acerto, perc_erros, perc_nao_preditos

Scores_TinyBerta = calcular_acertos(df, 'conjunto_verdade', 'TinyBerta')
Scores_BertPT = calcular_acertos(df, 'conjunto_verdade', 'BertPT')
Scores_BertPT_V2 = calcular_acertos(df, 'conjunto_verdade', 'BertPT_V2')
Scores_SpacyEN = calcular_acertos(df, 'conjunto_verdade', 'SpacyEN')
Scores_SpacyPT = calcular_acertos(df, 'conjunto_verdade', 'SpacyPT')

#Adicionar os valores a um novo dataframe
df_scores = pd.DataFrame(columns=['Modelo', 'Total Itens', 'acuracia %', '% Acertos','% Erros', '% Não Predito'])

df_scores.loc[0] = ['TinyBerta'] + list(Scores_TinyBerta)
df_scores.loc[1] = ['BertPT'] + list(Scores_BertPT)
df_scores.loc[2] = ['BertPT_V2'] + list(Scores_BertPT_V2)
df_scores.loc[3] = ['SpacyEN'] + list(Scores_SpacyEN)
df_scores.loc[4] = ['SpacyPT'] + list(Scores_SpacyPT)
df_scores
# Out:
#       Modelo  Total Itens  acuracia %  % Acertos  % Erros  % Não Predito
# 0  TinyBerta           15          11         27       73             89
# 1     BertPT           12          28         83       17             72
# 2  BertPT_V2           31          36         42       58             64
# 3    SpacyEN           51          64         45       55             36
# 4    SpacyPT           70          89         46       54             11
